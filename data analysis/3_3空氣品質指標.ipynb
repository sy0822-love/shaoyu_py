# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&1imit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant status  so2    co  o3  o3_8hr  pm10  ...  \
# 0       基隆    基隆市   51      懸浮微粒     普通  1.0  0.36  24      47    31  ...
# 1       汐止    新北市   64     細懸浮微粒     普通  1.5  0.32  20      48    45  ...
# 2       萬里    新北市   63      懸浮微粒     普通  1.3  0.26  11      49    32  ...
# 3       新店    新北市   62     細懸浮微粒     普通  1.3  0.47  21      49    39  ...
# 4       土城    新北市   67     細懸浮微粒     普通  0.9  0.56  12      47    47  ...
#
#    wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 0         0.4         279  2025/04/27 21:00:00     0.2      11.5       31
# 1         0.4          35  2025/04/27 21:00:00     0.2      17.3       38
# 2         0.7         235  2025/04/27 21:00:00     0.2      12.1       42
# 3         0.5         149  2025/04/27 21:00:00     0.3      16.4       35
# 4         0.5         160  2025/04/27 21:00:00     0.3      18.2       40
#
#   so2_avg   longitude   latitude  siteid
# 0       1  121.760056  25.129167       1
# 1       1  121.640810  25.066240       2
# 2       1  121.689881  25.179667       3
# 3       0  121.537778  24.977222       4
# 4       0  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %%
df = df[['sitename', 'county', 'pollutant', 'status', 'aqi']]

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
# Empty DataFrame
# Columns: [sitename, county, pollutant, status, aqi]
# Index: []

# %%
df['pollutant'].unique()
# Out:
# array(['懸浮微粒', '細懸浮微粒', '臭氧八小時', nan, '二氧化氮'], dtype=object)

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 46       美濃    高雄市     臭氧八小時     普通   87
# 47       橋頭    高雄市     細懸浮微粒     普通   56
# 48       仁武    高雄市     細懸浮微粒     普通   63
# 49       鳳山    高雄市     細懸浮微粒     普通   67
# 50       大寮    高雄市     細懸浮微粒     普通   64
# 51       林園    高雄市     細懸浮微粒     普通   66
# 52       楠梓    高雄市     細懸浮微粒     普通   60
# 53       左營    高雄市     細懸浮微粒     普通   58
# 54       前金    高雄市     細懸浮微粒     普通   54
# 55       前鎮    高雄市     細懸浮微粒     普通   56
# 56       小港    高雄市     細懸浮微粒     普通   59
# 69       復興    高雄市     細懸浮微粒     普通   55
# 79   高雄(湖內)    高雄市      懸浮微粒     普通   53

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    100.000000
# 彰化縣     78.400000
# 嘉義縣     75.000000
# 嘉義市     73.000000
# 雲林縣     72.000000
# 南投縣     71.333333
# 連江縣     71.000000
# 屏東縣     67.400000
# 臺南市     65.600000
# 新竹市     65.000000
# 桃園市     64.666667
# 澎湖縣     64.000000
# 新北市     62.461538
# 臺北市     61.571429
# 高雄市     61.384615
# 臺中市     61.333333
# 苗栗縣     61.333333
# 新竹縣     60.000000
# 基隆市     51.000000
# 花蓮縣     41.000000
# 宜蘭縣     40.500000
# 臺東縣     37.000000
# Name: aqi, dtype: float64
